# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
 
train_data = pd.read_csv("Dataset/train.csv")
test_data = pd.read_csv("Dataset/test.csv")

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127037 entries, 0 to 127036
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    127037 non-null  int64
#  1   Gender                127037 non-null  object
#  2   Age                   127037 non-null  int64
#  3   Driving_License       127037 non-null  int64
#  4   Region_Code           127037 non-null  float64
#  5   Previously_Insured    127037 non-null  int64
#  6   Vehicle_Age           127037 non-null  object
#  7   Vehicle_Damage        127037 non-null  object
#  8   Annual_Premium        127037 non-null  float64
#  9   Policy_Sales_Channel  127037 non-null  float64
#  10  Vintage               127037 non-null  int64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 10.7+ MB

# %%
train_data.head(5)
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
print(train_data.shape)
print(test_data.shape)

print('Features : ', train_data.columns.values)
print('Features : ', test_data.columns.values)
train_data.head()
# Out:
# (381109, 12)
# (127037, 11)
# Features :  ['id' 'Gender' 'Age' 'Driving_License' 'Region_Code' 'Previously_Insured'
#  'Vehicle_Age' 'Vehicle_Damage' 'Annual_Premium' 'Policy_Sales_Channel'
#  'Vintage' 'Response']
# Features :  ['id' 'Gender' 'Age' 'Driving_License' 'Region_Code' 'Previously_Insured'
#  'Vehicle_Age' 'Vehicle_Damage' 'Annual_Premium' 'Policy_Sales_Channel'
#  'Vintage']
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
train_data.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# dtype: int64

# %%
train_data.nunique()
# Out:
# id                      381109
# Gender                       2
# Age                         66
# Driving_License              2
# Region_Code                 53
# Previously_Insured           2
# Vehicle_Age                  3
# Vehicle_Damage               2
# Annual_Premium           48838
# Policy_Sales_Channel       155
# Vintage                    290
# Response                     2
# dtype: int64

# %%
train_data.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# 25%              0.000000    24405.000000             29.000000
# 50%              0.000000    31669.000000            133.000000
# 75%              1.000000    39400.000000            152.000000
# max              1.000000   540165.000000            163.000000
#
#              Vintage       Response
# count  381109.000000  381109.000000
# mean      154.347397       0.122563
# std        83.671304       0.327936
# min        10.000000       0.000000
# 25%        82.000000       0.000000
# 50%       154.000000       0.000000
# 75%       227.000000       0.000000
# max       299.000000       1.000000

# %%
train_data["Response"].value_counts(normalize= True)
# Out:
# 0    0.877437
# 1    0.122563
# Name: Response, dtype: float64

# %%
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()
train_data[["Gender","Vehicle_Damage"]] = enc.fit_transform(train_data[["Gender","Vehicle_Damage"]])
test_data[["Gender","Vehicle_Damage"]] = enc.fit_transform(test_data[["Gender","Vehicle_Damage"]])

train_data.loc[train_data['Vehicle_Age'] == '> 2 Years', 'Vehicle_Age'] = 2
train_data.loc[train_data['Vehicle_Age'] == '1-2 Year', 'Vehicle_Age'] = 1
train_data.loc[train_data['Vehicle_Age'] == '< 1 Year', 'Vehicle_Age'] = 0
test_data.loc[test_data['Vehicle_Age'] == '> 2 Years', 'Vehicle_Age'] = 2
test_data.loc[test_data['Vehicle_Age'] == '1-2 Year', 'Vehicle_Age'] = 1
test_data.loc[test_data['Vehicle_Age'] == '< 1 Year', 'Vehicle_Age'] = 0

train_data['Vehicle_Age']=train_data['Vehicle_Age'].astype(float)
test_data['Vehicle_Age']=test_data['Vehicle_Age'].astype(float)


test_data.head()
# Out:
#        id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  381110     1.0   25                1         11.0                   1
# 1  381111     1.0   40                1         28.0                   0
# 2  381112     1.0   47                1         28.0                   0
# 3  381113     1.0   24                1         27.0                   1
# 4  381114     1.0   27                1         28.0                   1
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0          0.0             0.0         35786.0                 152.0       53
# 1          1.0             1.0         33762.0                   7.0      111
# 2          1.0             1.0         40050.0                 124.0      199
# 3          0.0             1.0         37356.0                 152.0      187
# 4          0.0             0.0         59097.0                 152.0      297

# %%
# draw boxplots to visualize outliers
has_outliers = ['Age', 'Annual_Premium', 'Vintage']

plt.figure(figsize=(10,7.5))

for i,col in enumerate(has_outliers):
    plt.subplot(1, 3, i+1)
    fig = train_data.boxplot(column=col)
    fig.set_title('')
    fig.set_ylabel(col)

# %%
has_outliers.remove('Age')
has_outliers.remove('Vintage')
up_outliers = []
low_outliers = []

def max_value(df, variable, top):
    return np.where(df[variable]>top, top, df[variable])


for col in has_outliers:
    IQR = train_data[col].quantile(0.75) - train_data[col].quantile(0.25)
    Lower_fence = train_data[col].quantile(0.25) - (1.5*IQR)
    Upper_fence = train_data[col].quantile(0.75) + (1.5*IQR)
    low_outliers.append(Lower_fence)
    up_outliers.append(Upper_fence)
    print(f'{col} outliers are values < {Lower_fence} or > {Upper_fence}')

for col, outlier in zip(has_outliers, up_outliers):
    train_data[col] = max_value(train_data, col, outlier)

# També per el Test set

for col in has_outliers:
    IQR = test_data[col].quantile(0.75) - test_data[col].quantile(0.25)
    Lower_fence = test_data[col].quantile(0.25) - (1.5*IQR)
    Upper_fence = test_data[col].quantile(0.75) + (1.5*IQR)
    low_outliers.append(Lower_fence)
    up_outliers.append(Upper_fence)
    print(f'{col} outliers are values < {Lower_fence} or > {Upper_fence}')

for col, outlier in zip(has_outliers, up_outliers):
    test_data[col] = max_value(test_data, col, outlier)

test_data.head()
# Out:
# Annual_Premium outliers are values < 1912.5 or > 61892.5
# Annual_Premium outliers are values < 1700.5 or > 62032.5
#        id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  381110     1.0   25                1         11.0                   1
# 1  381111     1.0   40                1         28.0                   0
# 2  381112     1.0   47                1         28.0                   0
# 3  381113     1.0   24                1         27.0                   1
# 4  381114     1.0   27                1         28.0                   1
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0          0.0             0.0         35786.0                 152.0       53
# 1          1.0             1.0         33762.0                   7.0      111
# 2          1.0             1.0         40050.0                 124.0      199
# 3          0.0             1.0         37356.0                 152.0      187
# 4          0.0             0.0         59097.0                 152.0      297

# %%
sns.countplot(train_data["Response"])
# Out:
# C:\Users\Mainur Rahman\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Response', ylabel='count'>

# %%
sns.distplot(train_data.Age)
# Out:
# C:\Users\Mainur Rahman\anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(y = 'Age', data = train_data)
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=train_data['Age'],y=train_data['Annual_Premium'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Annual_Premium'>

# %%
sns.countplot(train_data.Gender)
# Out:
# C:\Users\Mainur Rahman\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(train_data.Previously_Insured)
# Out:
# C:\Users\Mainur Rahman\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Previously_Insured', ylabel='count'>

# %%
sns.countplot(train_data.Vehicle_Age)
# Out:
# C:\Users\Mainur Rahman\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Vehicle_Age', ylabel='count'>

# %%
sns.countplot(train_data.Vehicle_Damage)
# Out:
# C:\Users\Mainur Rahman\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Vehicle_Damage', ylabel='count'>

# %%
sns.distplot(train_data.Annual_Premium)
# Out:
# C:\Users\Mainur Rahman\anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Annual_Premium', ylabel='Density'>

# %%
sns.boxplot(y = 'Annual_Premium', data = train_data)
# Out:
# <AxesSubplot:ylabel='Annual_Premium'>

# %%
sns.distplot(train_data.Vintage)
# Out:
# C:\Users\Mainur Rahman\anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Vintage', ylabel='Density'>

# %%
# train_data['Gender'] = train_data['Gender'].map( {'Female': 0, 'Male': 1} ).astype(int)

# %%
train_data=pd.get_dummies(train_data,drop_first=True)

# %%
train_data.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1     1.0   44                1         28.0                   0
# 1   2     1.0   76                1          3.0                   0
# 2   3     1.0   47                1         28.0                   0
# 3   4     1.0   21                1         11.0                   1
# 4   5     0.0   29                1         41.0                   1
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0          2.0             1.0         40454.0                  26.0      217
# 1          1.0             0.0         33536.0                  26.0      183
# 2          2.0             1.0         38294.0                  26.0       27
# 3          0.0             0.0         28619.0                 152.0      203
# 4          0.0             0.0         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# train_data=train_data.rename(columns={"Vehicle_Age_< 1 Year": "Vehicle_Age_lt_1_Year", "Vehicle_Age_> 2 Years": "Vehicle_Age_gt_2_Years"})
# train_data['Vehicle_Age_lt_1_Year']=train_data['Vehicle_Age_lt_1_Year'].astype('int')
# train_data['Vehicle_Age_gt_2_Years']=train_data['Vehicle_Age_gt_2_Years'].astype('int')
# train_data['Vehicle_Damage_Yes']=train_data['Vehicle_Damage_Yes'].astype('int')

# %%
# train_data.head()

# %%
# numeric_features = ['Age','Vintage']

# from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, RobustScaler
# ss = StandardScaler()
# train_data[numeric_features] = ss.fit_transform(train_data[numeric_features])


# mm = MinMaxScaler()
# train_data[['Annual_Premium']] = mm.fit_transform(train_data[['Annual_Premium']])

# %%
# train_data=train_data.drop('id',axis=1)

# %%
# test_data['Gender'] = test_data['Gender'].map( {'Female': 0, 'Male': 1} ).astype(int)
# test_data=pd.get_dummies(test_data,drop_first=True)
# test_data=test_data.rename(columns={"Vehicle_Age_< 1 Year": "Vehicle_Age_lt_1_Year", 
#                                     "Vehicle_Age_> 2 Years": "Vehicle_Age_gt_2_Years"})
# test_data['Vehicle_Age_lt_1_Year']=test_data['Vehicle_Age_lt_1_Year'].astype('int')
# test_data['Vehicle_Age_gt_2_Years']=test_data['Vehicle_Age_gt_2_Years'].astype('int')
# test_data['Vehicle_Damage_Yes']=test_data['Vehicle_Damage_Yes'].astype('int')

# %%
# test_data[numeric_features] = ss.transform(test_data[numeric_features])


# mm = MinMaxScaler()
# test_data[['Annual_Premium']] = mm.fit_transform(test_data[['Annual_Premium']])

# %%
plt.figure(figsize=(12,8))
sns.heatmap(train_data.corr(), annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
train_data.corr()['Response'].drop('Response').sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
id=test_data.id
test_data=test_data.drop('id',axis=1)

# %%
from sklearn.model_selection import train_test_split

train_target=train_data['Response']
train_data=train_data.drop(['Response'], axis = 1)
x_train,x_test,y_train,y_test = train_test_split(train_data,train_target, random_state = 0)

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\mainur rahman\anaconda3\envs\tensorflow\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\mainur rahman\anaconda3\envs\tensorflow\lib\site-packages (from imblearn) (0.7.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\mainur rahman\anaconda3\envs\tensorflow\lib\site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\mainur rahman\anaconda3\envs\tensorflow\lib\site-packages (from imbalanced-learn->imblearn) (1.19.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\mainur rahman\anaconda3\envs\tensorflow\lib\site-packages (from imbalanced-learn->imblearn) (1.0.0)
# Requirement already satisfied: scikit-learn>=0.23 in c:\users\mainur rahman\anaconda3\envs\tensorflow\lib\site-packages (from imbalanced-learn->imblearn) (0.23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mainur rahman\anaconda3\envs\tensorflow\lib\site-packages (from scikit-learn>=0.23->imbalanced-learn->imblearn) (2.1.0)

# %%
# from imblearn.over_sampling import SMOTE
# sm = SMOTE(random_state=2)
# x_train, y_train = sm.fit_sample(x_train, y_train)

# %%
#Create Nural Network
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import r2_score
from keras import backend as K

# %%
K.clear_session()

# %%
model = Sequential()


model.add(Dense(128, activation='relu', input_shape= (x_train.shape[1],)))  #input
model.add(Dropout(0.5))


model.add(Dense(84, activation='relu')) #hidden
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu')) #hidden
model.add(Dropout(0.5))

model.add(Dense(20, activation='relu')) #hidden
model.add(Dropout(0.5))

# %%
model.add(Dense(units=1, activation='sigmoid')) #output

# %%
opt = Adam(learning_rate=0.01)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=7)


model.fit(x=x_train, y=y_train, epochs=100, batch_size=128, verbose=1, shuffle=True, validation_data=(x_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/100
# 2234/2234 [==============================] - 7s 3ms/step - loss: 256.3547 - accuracy: 0.8346 - val_loss: 0.3852 - val_accuracy: 0.8775
# Epoch 2/100
# 2234/2234 [==============================] - 7s 3ms/step - loss: 2.0456 - accuracy: 0.8729 - val_loss: 0.3720 - val_accuracy: 0.8775
# Epoch 3/100
# 2234/2234 [==============================] - 7s 3ms/step - loss: 0.6409 - accuracy: 0.8764 - val_loss: 0.3719 - val_accuracy: 0.8775
# Epoch 4/100
# 2234/2234 [==============================] - 7s 3ms/step - loss: 0.4957 - accuracy: 0.8771 - val_loss: 0.3719 - val_accuracy: 0.8775
# Epoch 5/100
# 2234/2234 [==============================] - 7s 3ms/step - loss: 0.4035 - accuracy: 0.8773 - val_loss: 0.3719 - val_accuracy: 0.8775
# Epoch 6/100
# 2234/2234 [==============================] - 7s 3ms/step - loss: 0.3906 - accuracy: 0.8774 - val_loss: 0.3720 - val_accuracy: 0.8775
# Epoch 7/100
# 2234/2234 [==============================] - 7s 3ms/step - loss: 0.3850 - accuracy: 0.8774 - val_loss: 0.3719 - val_accuracy: 0.8775
# Epoch 8/100
# 2234/2234 [==============================] - 7s 3ms/step - loss: 0.3789 - accuracy: 0.8774 - val_loss: 0.3719 - val_accuracy: 0.8775
# Epoch 9/100
# 2234/2234 [==============================] - 7s 3ms/step - loss: 0.3741 - accuracy: 0.8774 - val_loss: 0.3720 - val_accuracy: 0.8775
# Epoch 10/100
# 2234/2234 [==============================] - 8s 3ms/step - loss: 0.4013 - accuracy: 0.8774 - val_loss: 0.3720 - val_accuracy: 0.8775
# Epoch 11/100
# 2234/2234 [==============================] - 7s 3ms/step - loss: 0.3896 - accuracy: 0.8774 - val_loss: 0.3719 - val_accuracy: 0.8775
# Epoch 12/100
# 2234/2234 [==============================] - 7s 3ms/step - loss: 0.3887 - accuracy: 0.8774 - val_loss: 0.3720 - val_accuracy: 0.8775
# Epoch 13/100
# 2234/2234 [==============================] - 7s 3ms/step - loss: 0.3950 - accuracy: 0.8774 - val_loss: 0.3719 - val_accuracy: 0.8775
# Epoch 14/100
# 2234/2234 [==============================] - 8s 3ms/step - loss: 0.3894 - accuracy: 0.8774 - val_loss: 0.3719 - val_accuracy: 0.8775
# Epoch 15/100
#  174/2234 [=>............................] - ETA: 6s - loss: 0.3734 - accuracy: 0.8767

# %%
pred = model.predict_classes(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, f1_score, \
    recall_score, classification_report, precision_score

print(classification_report(y_test, pred))

# %%
accuracy = accuracy_score(y_test, pred)
precision = precision_score(y_test, pred)
confusion = confusion_matrix(y_test, pred)
recall = recall_score(y_test, pred)
f1 = f1_score(y_test, pred)

print('accuracy: ', accuracy)

# %%
print('recall: ', recall)

# %%
print('precision: ', precision)

# %%
print('f1_score: ', f1)

# %%
print('ROC AUC Score:', roc_auc_score(y_test, pred, average = 'weighted'))

# %%
# print('confusion matrix:')
# print(confusion)

tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
tn, fp, fn, tp
